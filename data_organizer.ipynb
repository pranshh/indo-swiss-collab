# %%
import pandas as pd
import glob
import os

# %%
parquet_files = glob.glob(os.path.join("publications_oa_parquet", '*.parquet'))

# %%
for file in parquet_files:
    print(f"--- {os.path.basename(file)} ---")
    df = pd.read_parquet(file)
    print(df.head())  # Show first few rows of each file
    print(df.info())  # Show DataFrame info
    print("\n")
# Out:
# --- authorships_2000-01-01_2007-12-31.parquet ---
#                             work_id     display_name                orcid  \
# 0  https://openalex.org/W2128158076   S. Agostinelli                 None
# 1  https://openalex.org/W2128158076  John E. Allison  0000-0003-4108-4709
# 2  https://openalex.org/W2128158076         B. R. Ko  0000-0002-4591-5269
# 3  https://openalex.org/W2128158076   J. Apostolakis  0000-0003-1184-3727
# 4  https://openalex.org/W2128158076     H. M. Araújo  0000-0002-5972-2783
#
#   author_position  is_corresponding  \
# 0           first             False
# 1          middle             False
# 2          middle             False
# 3          middle             False
# 4          middle             False
#
#                                         affiliations  \
# 0  [{"inst_id":"I83816512","display_name":"Univer...
# 1  [{"inst_id":"I28407311","display_name":"Univer...
# 2  [{"inst_id":"I138728355","display_name":"High ...
# 3  [{"inst_id":"I67311998","display_name":"Europe...
# 4  [{"inst_id":"I47508984","display_name":"Imperi...
#
#                                      affiliation_raw    author_id
# 0                  University of Genoa, Genoa, Italy  A5019950553
# 1  University of Manchester, Manchester, United K...  A5102846098
# 2  High Energy Accelerator Research Organization,...  A5009376065
# 3  European Organization for Nuclear Research, Ge...  A5056196917
# 4    Imperial College London, London, United Kingdom  A5075976624
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105697 entries, 0 to 105696
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   work_id           105697 non-null  object
#  1   display_name      105697 non-null  object
#  2   orcid             38522 non-null   object
#  3   author_position   105697 non-null  object
#  4   is_corresponding  105697 non-null  bool
#  5   affiliations      94807 non-null   object
#  6   affiliation_raw   96024 non-null   object
#  7   author_id         105697 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 5.7+ MB
# None
#
#
# --- authorships_2008-01-01_2012-12-31.parquet ---
#        work_id       display_name                orcid author_position  \
# 0  W2110052313      Stephen S Lim                 None           first
# 1  W2110052313           Theo Vos  0000-0002-5690-5365          middle
# 2  W2110052313  Abraham D Flaxman                 None          middle
# 3  W2110052313     Goodarz Danaei                 None          middle
# 4  W2110052313      Kenji Shibuya  0000-0003-2528-7530          middle
#
#    is_corresponding                                       affiliations  \
# 0              True  [{"inst_id":"I3143470655","display_name":"Inst...
# 1             False                                               None
# 2             False  [{"inst_id":"I3143470655","display_name":"Inst...
# 3             False  [{"inst_id":"I136199984","display_name":"Harva...
# 4             False                                               None
#
#                                      affiliation_raw    author_id
# 0  Institute for Health Metrics and Evaluation, S...  A5112677199
# 1  School of Population Health, Brisbane, QLD, Au...  A5007119101
# 2  Institute for Health Metrics and Evaluation, S...  A5108084990
# 3  School of Public Health, Harvard University, B...  A5107869833
# 4   Department of Global Health Policy, Tokyo, Japan  A5082274727
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94717 entries, 0 to 94716
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   work_id           94717 non-null  object
#  1   display_name      94717 non-null  object
#  2   orcid             43904 non-null  object
#  3   author_position   94717 non-null  object
#  4   is_corresponding  94717 non-null  bool
#  5   affiliations      88125 non-null  object
#  6   affiliation_raw   90739 non-null  object
#  7   author_id         94717 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 5.1+ MB
# None
#
#
# --- authorships_2013-01-01_2016-12-31.parquet ---
#        work_id            display_name                orcid author_position  \
# 0  W1757407923          Jacques Ferlay  0000-0003-4927-6932           first
# 1  W1757407923  Isabelle Soerjomataram  0000-0002-6017-741X          middle
# 2  W1757407923          Rajesh Dikshit  0000-0003-4830-0486          middle
# 3  W1757407923             Sultan Eser  0000-0003-4427-4540          middle
# 4  W1757407923           Colin Mathers  0000-0002-0617-6731          middle
#
#    is_corresponding                                       affiliations  \
# 0             False  [{"inst_id":"I42237331","display_name":"Centre...
# 1             False  [{"inst_id":"I42237331","display_name":"Centre...
# 2             False  [{"inst_id":"I2800098698","display_name":"Tata...
# 3             False  [{"inst_id":"I66514158","display_name":"Hacett...
# 4             False  [{"inst_id":"I4210105654","display_name":"Worl...
#
#                                      affiliation_raw    author_id
# 0  Section of Cancer Surveillance, International ...  A5051830072
# 1  Section of Cancer Surveillance, International ...  A5057880586
# 2             Tata Memorial Hospital, Mumbai, India.  A5049513467
# 3  Izmir Cancer Registry, Izmir Hub, Izmir and Ha...  A5025276497
# 4  Department of Measurement and Health Informati...  A5017081649
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174307 entries, 0 to 174306
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   work_id           174307 non-null  object
#  1   display_name      174307 non-null  object
#  2   orcid             82140 non-null   object
#  3   author_position   174307 non-null  object
#  4   is_corresponding  174307 non-null  bool
#  5   affiliations      160301 non-null  object
#  6   affiliation_raw   164227 non-null  object
#  7   author_id         174307 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 9.5+ MB
# None
#
#
# --- authorships_2017-01-01_2019-12-31.parquet ---
#        work_id       display_name                orcid author_position  \
# 0  W2909678677  Walter C. Willett  0000-0003-1458-7597           first
# 1  W2909678677    Johan Rockström  0000-0001-8988-2983          middle
# 2  W2909678677        Brent Loken  0000-0002-0068-3142          middle
# 3  W2909678677   Marco Springmann  0000-0001-6028-5712          middle
# 4  W2909678677           Tim Lang                 None          middle
#
#    is_corresponding                                       affiliations  \
# 0             False  [{"inst_id":"I1283280774","display_name":"Brig...
# 1             False  [{"inst_id":"I138595864","display_name":"Stock...
# 2              True  [{"inst_id":"I138595864","display_name":"Stock...
# 3             False  [{"inst_id":"I40120149","display_name":"Univer...
# 4             False  [{"inst_id":"I180825142","display_name":"City,...
#
#                                      affiliation_raw    author_id
# 0  Harvard T H Chan School of Public Health, Harv...  A5083991449
# 1  Potsdam Institute for Climate Impact Research,...  A5038584174
# 2                                  EAT, Oslo, Norway  A5006608117
# 3  Oxford Martin Programme on the Future of Food ...  A5077458864
# 4  Centre for Food Policy, City, University of Lo...  A5111456834
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184560 entries, 0 to 184559
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   work_id           184560 non-null  object
#  1   display_name      184560 non-null  object
#  2   orcid             100684 non-null  object
#  3   author_position   184560 non-null  object
#  4   is_corresponding  184560 non-null  bool
#  5   affiliations      173011 non-null  object
#  6   affiliation_raw   177597 non-null  object
#  7   author_id         184560 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 10.0+ MB
# None
#
#
# --- authorships_2020-01-01_2021-12-31.parquet ---
#        work_id    display_name                orcid author_position  \
# 0  W4288079944      N. Aghanim                 None           first
# 1  W4288079944       Y. Akrami  0000-0002-2407-7956          middle
# 2  W4288079944      M. Ashdown                 None          middle
# 3  W4288079944       J. Aumont  0000-0001-6279-0691          middle
# 4  W4288079944  C. Baccigalupi                 None          middle
#
#    is_corresponding                                       affiliations  \
# 0             False  [{"inst_id":"I277688954","display_name":"Unive...
# 1             False  [{"inst_id":"I29607241","display_name":"École ...
# 2             False  [{"inst_id":"I241749","display_name":"Universi...
# 3             False  [{"inst_id":"I17866349","display_name":"Univer...
# 4             False  [{"inst_id":"I138549579","display_name":"Scuol...
#
#                                      affiliation_raw    author_id
# 0  Institut d'Astrophysique Spatiale, CNRS, Univ....  A5107856445
# 1  Département de Physique, École normale supérie...  A5091142009
# 2  Astrophysics Group, Cavendish Laboratory, Univ...  A5107906415
# 3  Université de Toulouse, UPS-OMP, IRAP, 31028 T...  A5079989482
# 4  SISSA, Astrophysics Sector, Via Bonomea 265, 3...  A5107906348
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164134 entries, 0 to 164133
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   work_id           164134 non-null  object
#  1   display_name      164134 non-null  object
#  2   orcid             97497 non-null   object
#  3   author_position   164134 non-null  object
#  4   is_corresponding  164134 non-null  bool
#  5   affiliations      154614 non-null  object
#  6   affiliation_raw   159691 non-null  object
#  7   author_id         164134 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 8.9+ MB
# None
#
#
# --- authorships_2022-01-01_2023-12-31.parquet ---
#        work_id    display_name                orcid author_position  \
# 0  W2963002078  Ronald Workman                 None           first
# 1  W2963002078  Volker Burkert  0000-0003-4747-0838          middle
# 2  W2963002078        V. Credé                 None          middle
# 3  W2963002078       E. Klempt  0000-0003-4179-9405          middle
# 4  W2963002078        U. Thoma  0000-0002-9935-3134          middle
#
#    is_corresponding                                       affiliations  \
# 0             False  [{"inst_id":"I193531525","display_name":"Georg...
# 1             False  [{"inst_id":"I29801172","display_name":"Thomas...
# 2             False  [{"inst_id":"I103163165","display_name":"Flori...
# 3             False  [{"inst_id":"I135140700","display_name":"Unive...
# 4             False  [{"inst_id":"I135140700","display_name":"Unive...
#
#                                      affiliation_raw    author_id
# 0  George Washington University, Department of Ph...  A5012477529
# 1             Jefferson Lab , Newport News, VA , USA  A5105351811
# 2  Florida State University, Department of Physic...  A5107856956
# 3  Universität Bonn, Helmholtz-Institut für Strah...  A5073768312
# 4  Universität Bonn, Helmholtz-Institut für Strah...  A5068342999
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191787 entries, 0 to 191786
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   work_id           191787 non-null  object
#  1   display_name      191787 non-null  object
#  2   orcid             135553 non-null  object
#  3   author_position   191787 non-null  object
#  4   is_corresponding  191787 non-null  bool
#  5   affiliations      175581 non-null  object
#  6   affiliation_raw   180942 non-null  object
#  7   author_id         191787 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 10.4+ MB
# None
#
#
# --- authorships_2024-01-01_2024-12-31.parquet ---
#        work_id             display_name                orcid author_position  \
# 0  W4391649568           Joshua A Welsh  0000-0002-1097-9756           first
# 1  W4391649568  Deborah C. I. Goberdhan  0000-0003-0645-6714          middle
# 2  W4391649568      Lorraine O’Driscoll  0000-0002-9860-8262          middle
# 3  W4391649568            Edit I. Buzás  0000-0002-3744-206X          middle
# 4  W4391649568         Cherie Blenkiron  0000-0002-0217-3808          middle
#
#    is_corresponding                                       affiliations  \
# 0              True  [{"inst_id":"I4210140884","display_name":"Nati...
# 1              True  [{"inst_id":"I2802742124","display_name":"John...
# 2              True  [{"inst_id":"I205274468","display_name":"Trini...
# 3             False  [{"inst_id":"I101202996","display_name":"Semme...
# 4             False  [{"inst_id":"I154130895","display_name":"Unive...
#
#                                      affiliation_raw    author_id
# 0                              ISEV Board 2020-2022.  A5046116488
# 1                              ISEV Board 2020-2022.  A5023020968
# 2                              ISEV Board 2020-2022.  A5025907836
# 3  Department of Genetics, Cell- and Immunobiolog...  A5086107375
# 4  Faculty of Medical and Health Sciences, The Un...  A5049860411
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85424 entries, 0 to 85423
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   work_id           85424 non-null  object
#  1   display_name      85424 non-null  object
#  2   orcid             64022 non-null  object
#  3   author_position   85424 non-null  object
#  4   is_corresponding  85424 non-null  bool
#  5   affiliations      77513 non-null  object
#  6   affiliation_raw   81315 non-null  object
#  7   author_id         85424 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 4.6+ MB
# None
#
#
# --- authorships_from_WoS-Scopus_1.parquet ---
#                             work_id           display_name  \
# 0  https://openalex.org/W2982806384  Mariachiara Di Cesare
# 1  https://openalex.org/W2982806384           Maroje Sorić
# 2  https://openalex.org/W2982806384           Pascal Bovet
# 3  https://openalex.org/W2982806384       J. Jaime Miranda
# 4  https://openalex.org/W2982806384      Zulfiqar A Bhutta
#
#                  orcid author_position  is_corresponding  \
# 0  0000-0002-3934-3364           first              True
# 1  0000-0001-6835-1438          middle             False
# 2  0000-0002-0242-4259          middle             False
# 3  0000-0002-4738-5468          middle             False
# 4  0000-0003-0637-599X          middle             False
#
#                                         affiliations  \
# 0  [{"inst_id":"I60488453","display_name":"Middle...
# 1  [{"inst_id":"I181343428","display_name":"Unive...
# 2                                               None
# 3  [{"inst_id":"I197097402","display_name":"Unive...
# 4  [{"inst_id":"I118185606","display_name":"Aga K...
#
#                                      affiliation_raw    author_id
# 0  Middlesex University, The Burroughs, London, N...  A5061675894
# 1  University of Zagreb, Trg Republike Hrvatske 1...  A5046914048
# 2  Center for Primary Care and Public Health, Sec...  A5076937097
# 3  Universidad Peruana Cayetano Heredia, Av. Hono...  A5013597377
# 4  Aga Khan University, National Stadium Rd, Kara...  A5031009188
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56225 entries, 0 to 56224
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   work_id           56225 non-null  object
#  1   display_name      56225 non-null  object
#  2   orcid             39920 non-null  object
#  3   author_position   56225 non-null  object
#  4   is_corresponding  56225 non-null  bool
#  5   affiliations      40209 non-null  object
#  6   affiliation_raw   46316 non-null  object
#  7   author_id         56225 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 3.1+ MB
# None
#
#
# --- authorships_from_WoS-Scopus_2-1.parquet ---
#                             work_id     display_name                orcid  \
# 0  https://openalex.org/W2786888677           G. Aad  0000-0002-6665-4934
# 1  https://openalex.org/W2786888677       T. Abajyan                 None
# 2  https://openalex.org/W2786888677        B. Abbott  0000-0002-5888-2734
# 3  https://openalex.org/W2786888677      J. Abdallah                 None
# 4  https://openalex.org/W2786888677  S. Abdel Khalek                 None
#
#   author_position  is_corresponding  \
# 0           first             False
# 1          middle             False
# 2          middle             False
# 3          middle             False
# 4          middle             False
#
#                                         affiliations  \
# 0  [{"id":"https://openalex.org/I1294671590","dis...
# 1  [{"id":"https://openalex.org/I135140700","disp...
# 2  [{"id":"https://openalex.org/I8692664","displa...
# 3  [{"id":"https://openalex.org/I4210111779","dis...
# 4  [{"id":"https://openalex.org/I102197404","disp...
#
#                                      affiliation_raw    author_id
# 0  CPPM, Aix-Marseille Université and CNRS/IN2P3,...  A5100769897
# 1  Physikalisches Institut, University of Bonn, B...  A5033435943
# 2  Homer L. Dodge Department of Physics and Astro...  A5007910787
# 3  Institute of Physics, Academia Sinica, Taipei,...  A5107847063
# 4  LAL, Université Paris-Sud and CNRS/IN2P3, Orsa...  A5107857122
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660342 entries, 0 to 660341
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   work_id           660342 non-null  object
#  1   display_name      660342 non-null  object
#  2   orcid             253692 non-null  object
#  3   author_position   660342 non-null  object
#  4   is_corresponding  660342 non-null  bool
#  5   affiliations      660342 non-null  object
#  6   affiliation_raw   626500 non-null  object
#  7   author_id         660342 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 35.9+ MB
# None
#
#
# --- authorships_from_WoS-Scopus_2-2.parquet ---
#                             work_id        display_name                orcid  \
# 0  https://openalex.org/W4293088723        P. A. R. Ade  0000-0002-5127-0401
# 1  https://openalex.org/W4293088723          N. Aghanim                 None
# 2  https://openalex.org/W4293088723           M. Arnaud                 None
# 3  https://openalex.org/W4293088723          M. Ashdown                 None
# 4  https://openalex.org/W4293088723  F. Atrio‐Barandela  0000-0002-2130-2513
#
#   author_position  is_corresponding  \
# 0           first             False
# 1          middle             False
# 2          middle             False
# 3          middle             False
# 4          middle             False
#
#                                         affiliations  \
# 0  [{"id":"https://openalex.org/I79510175","displ...
# 1  [{"id":"https://openalex.org/I1294671590","dis...
# 2  [{"id":"https://openalex.org/I169173203","disp...
# 3  [{"id":"https://openalex.org/I241749","display...
# 4  [{"id":"https://openalex.org/I184999862","disp...
#
#                                      affiliation_raw    author_id
# 0  School of Physics and Astronomy, Cardiff Unive...  A5018475357
# 1  Institut d'Astrophysique Spatiale, CNRS (UMR 8...  A5107856445
# 2  Laboratoire AIM, IRFU/Service d'Astrophysique ...  A5105938337
# 3  Astrophysics Group, Cavendish Laboratory, Univ...  A5107858497
# 4  Departamento de Física Fundamental, Facultad d...  A5091365621
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553796 entries, 0 to 553795
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   work_id           553796 non-null  object
#  1   display_name      553796 non-null  object
#  2   orcid             199724 non-null  object
#  3   author_position   553796 non-null  object
#  4   is_corresponding  553796 non-null  bool
#  5   affiliations      553796 non-null  object
#  6   affiliation_raw   521201 non-null  object
#  7   author_id         553796 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 30.1+ MB
# None
#
#
# --- authorships_from_WoS-Scopus_2-3.parquet ---
#                             work_id display_name                orcid  \
# 0  https://openalex.org/W2161586006   A. Garmash                 None
# 1  https://openalex.org/W2161586006       K. Abe                 None
# 2  https://openalex.org/W2161586006       K. Abe                 None
# 3  https://openalex.org/W2161586006       K. Abe  0000-0002-0876-8319
# 4  https://openalex.org/W2161586006       K. Abe  0000-0002-0876-8319
#
#   author_position  is_corresponding  \
# 0           first             False
# 1          middle             False
# 2          middle             False
# 3          middle             False
# 4          middle             False
#
#                                         affiliations  \
# 0  [{"id":"https://openalex.org/I4843557","displa...
# 1  [{"id":"https://openalex.org/I138728355","disp...
# 2  [{"id":"https://openalex.org/I138728355","disp...
# 3  [{"id":"https://openalex.org/I114531698","disp...
# 4  [{"id":"https://openalex.org/I201537933","disp...
#
#                                      affiliation_raw    author_id
# 0   Budker Institute of Nuclear Physics, Novosibirsk  A5109050521
# 1  High Energy Accelerator Research Organization ...  A5108101488
# 2  High Energy Accelerator Research Organization ...  A5108101488
# 3               Tokyo Institute of Technology, Tokyo  A5055484840
# 4                          Tohoku University, Sendai  A5055484840
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517091 entries, 0 to 517090
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   work_id           517091 non-null  object
#  1   display_name      517091 non-null  object
#  2   orcid             364688 non-null  object
#  3   author_position   517091 non-null  object
#  4   is_corresponding  517091 non-null  bool
#  5   affiliations      517091 non-null  object
#  6   affiliation_raw   362761 non-null  object
#  7   author_id         517091 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 28.1+ MB
# None
#
#
# --- authorships_from_WoS-Scopus_2-4.parquet ---
#                             work_id              display_name  \
# 0  https://openalex.org/W4384201411               A. Tumasyan
# 1  https://openalex.org/W4384201411                   W. Adam
# 2  https://openalex.org/W4384201411  Janik Walter Andrejkovic
# 3  https://openalex.org/W4384201411               T. Bergauer
# 4  https://openalex.org/W4384201411             S. Chatterjee
#
#                  orcid author_position  is_corresponding  \
# 0  0009-0000-0684-6742           first             False
# 1  0000-0001-9099-4341          middle             False
# 2                 None          middle             False
# 3  0000-0002-5786-0293          middle             False
# 4  0000-0003-2660-0349          middle             False
#
#                                         affiliations  \
# 0  [{"id":"https://openalex.org/I132091411","disp...
# 1  [{"id":"https://openalex.org/I4210129701","dis...
# 2  [{"id":"https://openalex.org/I4210129701","dis...
# 3  [{"id":"https://openalex.org/I4210129701","dis...
# 4  [{"id":"https://openalex.org/I4210129701","dis...
#
#                                    affiliation_raw    author_id
# 0      Yerevan Physics Institute, Yerevan, Armenia  A5069509278
# 1  Institut für Hochenergiephysik, Vienna, Austria  A5074924703
# 2  Institut für Hochenergiephysik, Vienna, Austria  A5105721937
# 3  Institut für Hochenergiephysik, Vienna, Austria  A5114334441
# 4  Institut für Hochenergiephysik, Vienna, Austria  A5114377741
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542084 entries, 0 to 542083
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   work_id           542084 non-null  object
#  1   display_name      542084 non-null  object
#  2   orcid             282279 non-null  object
#  3   author_position   542084 non-null  object
#  4   is_corresponding  542084 non-null  bool
#  5   affiliations      542084 non-null  object
#  6   affiliation_raw   498702 non-null  object
#  7   author_id         542084 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 29.5+ MB
# None
#
#
# --- authorships_from_WoS-Scopus_2-5.parquet ---
#                             work_id    display_name                orcid  \
# 0  https://openalex.org/W3010174447  A. M. Sirunyan                 None
# 1  https://openalex.org/W3010174447     A. Tumasyan  0009-0000-0684-6742
# 2  https://openalex.org/W3010174447         W. Adam                 None
# 3  https://openalex.org/W3010174447      F. Ambrogi                 None
# 4  https://openalex.org/W3010174447     T. Bergauer  0000-0002-5786-0293
#
#   author_position  is_corresponding  \
# 0           first             False
# 1          middle             False
# 2          middle             False
# 3          middle             False
# 4          middle             False
#
#                                         affiliations  \
# 0  [{"id":"https://openalex.org/I132091411","disp...
# 1  [{"id":"https://openalex.org/I132091411","disp...
# 2  [{"id":"https://openalex.org/I4210129701","dis...
# 3  [{"id":"https://openalex.org/I4210129701","dis...
# 4  [{"id":"https://openalex.org/I4210129701","dis...
#
#                                  affiliation_raw    author_id
# 0    Yerevan Physics Institute, Yerevan, Armenia  A5107826728
# 1    Yerevan Physics Institute, Yerevan, Armenia  A5069509278
# 2  Institut für Hochenergiephysik, Wien, Austria  A5106447234
# 3  Institut für Hochenergiephysik, Wien, Austria  A5107897710
# 4  Institut für Hochenergiephysik, Wien, Austria  A5114334441
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368509 entries, 0 to 368508
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   work_id           368509 non-null  object
#  1   display_name      368509 non-null  object
#  2   orcid             162700 non-null  object
#  3   author_position   368509 non-null  object
#  4   is_corresponding  368509 non-null  bool
#  5   affiliations      368509 non-null  object
#  6   affiliation_raw   320180 non-null  object
#  7   author_id         368509 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 20.0+ MB
# None
#
#
# --- authorships_from_WoS-Scopus_2-6.parquet ---
#                             work_id    display_name                orcid  \
# 0  https://openalex.org/W2900787975  A. M. Sirunyan                 None
# 1  https://openalex.org/W2900787975     A. Tumasyan                 None
# 2  https://openalex.org/W2900787975         W. Adam                 None
# 3  https://openalex.org/W2900787975      F. Ambrogi                 None
# 4  https://openalex.org/W2900787975       E. Asilar  0000-0001-5680-599X
#
#   author_position  is_corresponding  \
# 0           first             False
# 1          middle             False
# 2          middle             False
# 3          middle             False
# 4          middle             False
#
#                                         affiliations  \
# 0  [{"id":"https://openalex.org/I132091411","disp...
# 1  [{"id":"https://openalex.org/I132091411","disp...
# 2  [{"id":"https://openalex.org/I4210129701","dis...
# 3  [{"id":"https://openalex.org/I4210129701","dis...
# 4  [{"id":"https://openalex.org/I4210129701","dis...
#
#                                  affiliation_raw    author_id
# 0    Yerevan Physics Institute, Yerevan, Armenia  A5105551721
# 1    Yerevan Physics Institute, Yerevan, Armenia  A5105785020
# 2  Institut für Hochenergiephysik, Wien, Austria  A5105524158
# 3  Institut für Hochenergiephysik, Wien, Austria  A5106447054
# 4  Institut für Hochenergiephysik, Wien, Austria  A5007914806
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321508 entries, 0 to 321507
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   work_id           321508 non-null  object
#  1   display_name      321508 non-null  object
#  2   orcid             119593 non-null  object
#  3   author_position   321508 non-null  object
#  4   is_corresponding  321508 non-null  bool
#  5   affiliations      321508 non-null  object
#  6   affiliation_raw   301019 non-null  object
#  7   author_id         321508 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 17.5+ MB
# None
#
#
# --- authorships_from_WoS-Scopus_2-7.parquet ---
#                             work_id  display_name                orcid  \
# 0  https://openalex.org/W2597575550    R. Villari  0000-0001-7972-1676
# 1  https://openalex.org/W2597575550  P. Batistoni  0000-0002-2810-4229
# 2  https://openalex.org/W2597575550  J.P. Catalán  0000-0001-6599-1720
# 3  https://openalex.org/W2597575550    B. Colling                 None
# 4  https://openalex.org/W2597575550      D. Croft                 None
#
#   author_position  is_corresponding  \
# 0           first             False
# 1          middle             False
# 2          middle             False
# 3          middle             False
# 4          middle             False
#
#                                         affiliations  \
# 0  [{"id":"https://openalex.org/I110120368","disp...
# 1  [{"id":"https://openalex.org/I110120368","disp...
# 2  [{"id":"https://openalex.org/I178450904","disp...
# 3  [{"id":"https://openalex.org/I4210094962","dis...
# 4  [{"id":"https://openalex.org/I4210094962","dis...
#
#                                      affiliation_raw    author_id
# 0  ENEA, Department of Fusion and Nuclear Safety ...  A5073809659
# 1  ENEA, Department of Fusion and Nuclear Safety ...  A5050231002
# 2  Universidad Nacional de Educación a Distancia ...  A5044898254
# 3  Culham Science Centre, Abingdon, Oxon, OX14 3D...  A5086417619
# 4  Culham Science Centre, Abingdon, Oxon, OX14 3D...  A5112797930
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215826 entries, 0 to 215825
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   work_id           215826 non-null  object
#  1   display_name      215826 non-null  object
#  2   orcid             108656 non-null  object
#  3   author_position   215826 non-null  object
#  4   is_corresponding  215826 non-null  bool
#  5   affiliations      215826 non-null  object
#  6   affiliation_raw   167528 non-null  object
#  7   author_id         215826 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 11.7+ MB
# None
#
#
# --- authorships_from_WoS-Scopus_2-8.parquet ---
#                             work_id        display_name                orcid  \
# 0  https://openalex.org/W4320728084    Anastasia Kokori  0000-0002-3205-0147
# 1  https://openalex.org/W4320728084     Angelos Tsiaras  0000-0003-3840-1793
# 2  https://openalex.org/W4320728084       Billy Edwards  0000-0002-5494-3237
# 3  https://openalex.org/W4320728084        Adrian Jones                 None
# 4  https://openalex.org/W4320728084  Georgia Pantelidou  0000-0003-1040-0764
#
#   author_position  is_corresponding  \
# 0           first              True
# 1          middle              True
# 2          middle             False
# 3          middle              True
# 4          middle             False
#
#                                         affiliations  \
# 0  [{"id":"https://openalex.org/I45129253","displ...
# 1  [{"id":"https://openalex.org/I2799986158","dis...
# 2  [{"id":"https://openalex.org/I45129253","displ...
# 3  [{"id":"https://openalex.org/I206046368","disp...
# 4  [{"id":"https://openalex.org/I21370196","displ...
#
#                                      affiliation_raw    author_id
# 0  University College London, Gower Street, Londo...  A5050613522
# 1  INAF—Osservatorio Astrofisico di Arcetri, Larg...  A5017695033
# 2  AIM, CEA, CNRS, Université Paris-Saclay, Unive...  A5085986998
# 3                              Amateur Astronomer101  A5055607365
# 4  Department of Physics, Aristotle University of...  A5022780222
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245472 entries, 0 to 245471
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   work_id           245472 non-null  object
#  1   display_name      245472 non-null  object
#  2   orcid             138456 non-null  object
#  3   author_position   245472 non-null  object
#  4   is_corresponding  245472 non-null  bool
#  5   affiliations      245472 non-null  object
#  6   affiliation_raw   203440 non-null  object
#  7   author_id         245472 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 13.3+ MB
# None
#
#
# --- authorships_from_WoS-Scopus_3-1.parquet ---
#                             work_id  display_name                orcid  \
# 0  https://openalex.org/W2971836485  B. P. Abbott                 None
# 1  https://openalex.org/W2971836485     R. Abbott                 None
# 2  https://openalex.org/W2971836485  T. D. Abbott                 None
# 3  https://openalex.org/W2971836485    S. Abraham                 None
# 4  https://openalex.org/W2971836485   F. Acernese  0000-0003-3103-3473
#
#   author_position  is_corresponding  \
# 0           first             False
# 1          middle             False
# 2          middle             False
# 3          middle             False
# 4          middle             False
#
#                                         affiliations  \
# 0  [{"id":"https://openalex.org/I122411786","disp...
# 1  [{"id":"https://openalex.org/I122411786","disp...
# 2  [{"id":"https://openalex.org/I121820613","disp...
# 3  [{"id":"https://openalex.org/I59781447","displ...
# 4  [{"id":"https://openalex.org/I4210108560","dis...
#
#                                      affiliation_raw    author_id
# 0  LIGO, California Institute of Technology, Pasa...  A5109427038
# 1  LIGO, California Institute of Technology, Pasa...  A5107906377
# 2  Louisiana State University, Baton Rouge, Louis...  A5113097922
# 3  Inter-University Centre for Astronomy and Astr...  A5108126125
# 4  INFN, Sezione di Napoli, Complesso Universitar...  A5002195232
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542717 entries, 0 to 542716
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   work_id           542717 non-null  object
#  1   display_name      542717 non-null  object
#  2   orcid             226885 non-null  object
#  3   author_position   542717 non-null  object
#  4   is_corresponding  542717 non-null  bool
#  5   affiliations      542717 non-null  object
#  6   affiliation_raw   515938 non-null  object
#  7   author_id         542717 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 29.5+ MB
# None
#
#
# --- authorships_from_WoS-Scopus_3-2.parquet ---
#                             work_id            display_name  \
# 0  https://openalex.org/W2751884637                Theo Vos
# 1  https://openalex.org/W2751884637  Amanuel Alemu Abajobir
# 2  https://openalex.org/W2751884637   Kalkidan Hassen Abate
# 3  https://openalex.org/W2751884637      Cristiana Abbafati
# 4  https://openalex.org/W2751884637              Kaja Abbas
#
#                  orcid author_position  is_corresponding affiliations  \
# 0  0000-0002-5690-5365           first             False           []
# 1  0000-0002-6878-0627          middle             False           []
# 2  0000-0003-3486-2111          middle             False           []
# 3  0000-0003-2811-6251          middle             False           []
# 4  0000-0003-0563-1576          middle             False           []
#
#   affiliation_raw    author_id
# 0            None  A5007119101
# 1            None  A5028564284
# 2            None  A5102838811
# 3            None  A5022331752
# 4            None  A5020081921
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375639 entries, 0 to 375638
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   work_id           375639 non-null  object
#  1   display_name      375639 non-null  object
#  2   orcid             157215 non-null  object
#  3   author_position   375639 non-null  object
#  4   is_corresponding  375639 non-null  bool
#  5   affiliations      375639 non-null  object
#  6   affiliation_raw   343828 non-null  object
#  7   author_id         375639 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 20.4+ MB
# None
#
#
# --- publications_main_2000-01-01_2007-12-31.parquet ---
#                             work_id  \
# 0  https://openalex.org/W2128158076
# 1  https://openalex.org/W2125899728
# 2  https://openalex.org/W2144476887
# 3  https://openalex.org/W2101881391
# 4  https://openalex.org/W2170318505
#
#                                                title  \
# 0                        Geant4—a simulation toolkit
# 1  Comparison of Multiobjective Evolutionary Algo...
# 2                    No health without mental health
# 3  A Randomized Trial of Letrozole in Postmenopau...
# 4  Observation of a Narrow Charmoniumlike State i...
#
#                                         display_name  \
# 0                        Geant4—a simulation toolkit
# 1  Comparison of Multiobjective Evolutionary Algo...
# 2                    No health without mental health
# 3  A Randomized Trial of Letrozole in Postmenopau...
# 4  Observation of a Narrow Charmoniumlike State i...
#
#                                             abstract  \
# 0                                               None
# 1  In this paper, we provide a systematic compari...
# 2                                               None
# 3  In hormone-dependent breast cancer, five years...
# 4  We report the observation of a narrow charmoni...
#
#                                              doi publication_date  \
# 0  https://doi.org/10.1016/s0168-9002(03)01368-8       2003-06-21
# 1        https://doi.org/10.1162/106365600568202       2000-06-01
# 2  https://doi.org/10.1016/s0140-6736(07)61238-0       2007-09-01
# 3           https://doi.org/10.1056/nejmoa032312       2003-11-06
# 4  https://doi.org/10.1103/physrevlett.91.262001       2003-12-23
#
#    publication_year  cited_by_count  \
# 0              2003           22300
# 1              2000            5352
# 2              2007            3567
# 3              2003            1803
# 4              2003            1783
#
#                                                  ids     type  ...  \
# 0  ["https://openalex.org/W2128158076","https://d...  article  ...
# 1  ["https://openalex.org/W2125899728","https://d...  article  ...
# 2  ["https://openalex.org/W2144476887","https://d...   review  ...
# 3  ["https://openalex.org/W2101881391","https://d...   letter  ...
# 4  ["https://openalex.org/W2170318505","https://d...  article  ...
#
#                   host_organization         host_organization_name  \
# 0  https://openalex.org/P4310320990                    Elsevier BV
# 1  https://openalex.org/P4310315718                  The MIT Press
# 2  https://openalex.org/P4310320990                    Elsevier BV
# 3  https://openalex.org/P4310320239  Massachusetts Medical Society
# 4  https://openalex.org/P4310320261      American Physical Society
#
#                                 landing_page_url  \
# 0  https://doi.org/10.1016/s0168-9002(03)01368-8
# 1        https://doi.org/10.1162/106365600568202
# 2  https://doi.org/10.1016/s0140-6736(07)61238-0
# 3           https://doi.org/10.1056/nejmoa032312
# 4  https://doi.org/10.1103/physrevlett.91.262001
#
#                                              pdf_url license  \
# 0                                               None    None
# 1                                               None    None
# 2                                               None    None
# 3  https://www.nejm.org/doi/pdf/10.1056/NEJMoa032...    None
# 4                                               None    None
#
#             version                                             topics  \
# 0              None  [{"i":1,"score":0.9969,"id":"https://openalex....
# 1              None  [{"i":1,"score":0.9999,"id":"https://openalex....
# 2              None  [{"i":1,"score":0.9964,"id":"https://openalex....
# 3  publishedVersion  [{"i":1,"score":0.9999,"id":"https://openalex....
# 4              None  [{"i":1,"score":1,"id":"https://openalex.org/T...
#
#                                             keywords is_retracted grants
# 0  [{"id":"https://openalex.org/keywords/tracking...        False   None
# 1                                               null        False   None
# 2                                               null        False   None
# 3  [{"id":"https://openalex.org/keywords/letrozol...        False   None
# 4  [{"id":"https://openalex.org/keywords/kekb","d...        False   None
#
# [5 rows x 24 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1427 entries, 0 to 1426
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   work_id                 1427 non-null   object
#  1   title                   1420 non-null   object
#  2   display_name            1420 non-null   object
#  3   abstract                863 non-null    object
#  4   doi                     1345 non-null   object
#  5   publication_date        1427 non-null   object
#  6   publication_year        1427 non-null   int32
#  7   cited_by_count          1427 non-null   int32
#  8   ids                     1427 non-null   object
#  9   type                    1427 non-null   object
#  10  is_oa                   1408 non-null   object
#  11  source_display_name     1330 non-null   object
#  12  source_id               1330 non-null   object
#  13  issn_l                  1257 non-null   object
#  14  host_organization       1290 non-null   object
#  15  host_organization_name  1290 non-null   object
#  16  landing_page_url        1408 non-null   object
#  17  pdf_url                 206 non-null    object
#  18  license                 116 non-null    object
#  19  version                 336 non-null    object
#  20  topics                  1427 non-null   object
#  21  keywords                1427 non-null   object
#  22  is_retracted            1427 non-null   bool
#  23  grants                  5 non-null      object
# dtypes: bool(1), int32(2), object(21)
# memory usage: 246.8+ KB
# None
#
#
# --- publications_main_2008-01-01_2012-12-31.parquet ---
#        work_id                                              title  \
# 0  W2110052313  A comparative risk assessment of burden of dis...
# 1   W266195994                         Review of Particle Physics
# 2  W2145280166  Definition and classification of cancer cachex...
# 3  W2170121306  Global Biodiversity: Indicators of Recent Decl...
# 4  W2066907097           The State and Fate of Himalayan Glaciers
#
#                                         display_name  \
# 0  A comparative risk assessment of burden of dis...
# 1                         Review of Particle Physics
# 2  Definition and classification of cancer cachex...
# 3  Global Biodiversity: Indicators of Recent Decl...
# 4           The State and Fate of Himalayan Glaciers
#
#                                             abstract  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  Global Biodiversity Target Missed In 2002, the...
# 4  Himalayan glaciers are a focus of public and s...
#
#                               doi publication_date  publication_year  \
# 0   10.1016/s0140-6736(12)61766-8       2012-12-01              2012
# 1  10.1016/j.physletb.2008.07.018       2008-08-05              2008
# 2   10.1016/s1470-2045(10)70218-7       2011-02-05              2011
# 3         10.1126/science.1187512       2010-04-30              2010
# 4         10.1126/science.1215828       2012-04-19              2012
#
#    cited_by_count                                                ids     type  \
# 0           11593  ["https://openalex.org/W2110052313","https://d...  article
# 1            4925  ["https://openalex.org/W266195994","https://do...  article
# 2            4912  ["https://openalex.org/W2145280166","https://d...   review
# 3            4595  ["https://openalex.org/W2170121306","https://d...  article
# 4            2048  ["https://openalex.org/W2066907097","https://d...  article
#
#    ... host_organization                             host_organization_name  \
# 0  ...       P4310320990                                        Elsevier BV
# 1  ...       P4310320990                                        Elsevier BV
# 2  ...       P4310320990                                        Elsevier BV
# 3  ...       P4310315823  American Association for the Advancement of Sc...
# 4  ...       P4310315823  American Association for the Advancement of Sc...
#
#                                  landing_page_url pdf_url license  \
# 0   https://doi.org/10.1016/s0140-6736(12)61766-8    None    None
# 1  https://doi.org/10.1016/j.physletb.2008.07.018    None    None
# 2   https://doi.org/10.1016/s1470-2045(10)70218-7    None    None
# 3         https://doi.org/10.1126/science.1187512    None    None
# 4         https://doi.org/10.1126/science.1215828    None    None
#
#             version                                             topics  \
# 0              None  [{"i":1,"score":0.9954,"id":"https://openalex....
# 1              None  [{"i":1,"score":0.9866,"id":"https://openalex....
# 2              None  [{"i":1,"score":0.9997,"id":"https://openalex....
# 3  publishedVersion  [{"i":1,"score":0.9916,"id":"https://openalex....
# 4              None  [{"i":1,"score":1,"id":"https://openalex.org/T...
#
#                                             keywords is_retracted grants
# 0  [{"id":"https://openalex.org/keywords/attribut...        False   None
# 1  [{"id":"https://openalex.org/keywords/cabibbo–...        False   None
# 2  [{"id":"https://openalex.org/keywords/consensu...        False   None
# 3                                               null        False   None
# 4                                               null        False   None
#
# [5 rows x 24 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2030 entries, 0 to 2029
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   work_id                 2030 non-null   object
#  1   title                   2030 non-null   object
#  2   display_name            2030 non-null   object
#  3   abstract                1338 non-null   object
#  4   doi                     1934 non-null   object
#  5   publication_date        2030 non-null   object
#  6   publication_year        2030 non-null   int32
#  7   cited_by_count          2030 non-null   int32
#  8   ids                     2030 non-null   object
#  9   type                    2030 non-null   object
#  10  is_oa                   2000 non-null   object
#  11  source_display_name     1906 non-null   object
#  12  source_id               1906 non-null   object
#  13  issn_l                  1775 non-null   object
#  14  host_organization       1839 non-null   object
#  15  host_organization_name  1839 non-null   object
#  16  landing_page_url        2000 non-null   object
#  17  pdf_url                 496 non-null    object
# ...
# 1  https://doi.org/10.1103/physrevd.108.102004
# 2   https://doi.org/10.1038/s41531-023-00533-w
# 3   https://doi.org/10.1001/jamasurg.2023.2137
# 4   https://doi.org/10.1038/s41586-022-05599-9
#
#                                              pdf_url license  \
# 0  https://iopscience.iop.org/article/10.3847/153...   cc-by
# 1                                               None    None
# 2  https://www.nature.com/articles/s41531-023-005...   cc-by
# 3                                               None    None
# 4  https://www.nature.com/articles/s41586-022-055...   cc-by
#
#             version                                             topics  \
# 0  publishedVersion  [{"i":1,"score":0.9985,"id":"https://openalex....
# 1              None  [{"i":1,"score":0.9999,"id":"https://openalex....
# 2  publishedVersion  [{"i":1,"score":0.9974,"id":"https://openalex....
# 3              None  [{"i":1,"score":0.9999,"id":"https://openalex....
# 4  publishedVersion  [{"i":1,"score":0.9579,"id":"https://openalex....
#
#                                             keywords is_retracted  \
# 0  [{"id":"https://openalex.org/keywords/ephemeri...        False
# 1  [{"id":"https://openalex.org/keywords/annihila...        False
# 2                                               None        False
# 3  [{"id":"https://openalex.org/keywords/urinary-...        False
# 4                                               None        False
#
#                                               grants
# 0  ["https://openalex.org/F4320334632","Science a...
# 1  ["https://openalex.org/F4320306076","National ...
# 2  ["https://openalex.org/F4320306136","Michael J...
# 3                                               None
# 4                                               None
#
# [5 rows x 24 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226 entries, 0 to 225
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   work_id                 226 non-null    object
#  1   title                   226 non-null    object
#  2   display_name            226 non-null    object
#  3   abstract                177 non-null    object
#  4   doi                     226 non-null    object
#  5   publication_date        226 non-null    object
#  6   publication_year        226 non-null    int32
#  7   cited_by_count          226 non-null    int32
#  8   ids                     226 non-null    object
#  9   type                    226 non-null    object
#  10  is_oa                   226 non-null    bool
#  11  source_display_name     225 non-null    object
#  12  source_id               225 non-null    object
#  13  issn_l                  223 non-null    object
#  14  host_organization       223 non-null    object
#  15  host_organization_name  223 non-null    object
#  16  landing_page_url        226 non-null    object
#  17  pdf_url                 168 non-null    object
#  18  license                 185 non-null    object
#  19  version                 201 non-null    object
#  20  topics                  226 non-null    object
#  21  keywords                151 non-null    object
#  22  is_retracted            226 non-null    bool
#  23  grants                  82 non-null     object
# dtypes: bool(2), int32(2), object(20)
# memory usage: 37.6+ KB
# None
#
#
# --- publications_main_from_WoS-Scopus_3-1.parquet ---
#                             work_id  \
# 0  https://openalex.org/W2971836485
# 1  https://openalex.org/W2921342657
# 2  https://openalex.org/W2973189566
# 3  https://openalex.org/W2989608901
# 4  https://openalex.org/W2981612066
#
#                                                title  \
# 0  GWTC-1: A Gravitational-Wave Transient Catalog...
# 1  Global monitoring of antimicrobial resistance ...
# 2  Tests of general relativity with the binary bl...
# 3  The CAFA challenge reports improved protein fu...
# 4         Global distribution of earthworm diversity
#
#                                         display_name  \
# 0  GWTC-1: A Gravitational-Wave Transient Catalog...
# 1  Global monitoring of antimicrobial resistance ...
# 2  Tests of general relativity with the binary bl...
# 3  The CAFA challenge reports improved protein fu...
# 4         Global distribution of earthworm diversity
#
#                                             abstract  \
# 0  We present the results from three gravitationa...
# 1  Antimicrobial resistance (AMR) is a serious th...
# 2  The detection of gravitational waves by Advanc...
# 3  Abstract Background The Critical Assessment of...
# 4  Soil organisms, including earthworms, are a ke...
#
#                                            doi publication_date  \
# 0    https://doi.org/10.1103/physrevx.9.031040       2019-09-04
# 1   https://doi.org/10.1038/s41467-019-08853-3       2019-03-08
# 2  https://doi.org/10.1103/physrevd.100.104036       2019-11-20
# 3    https://doi.org/10.1186/s13059-019-1835-8       2019-11-19
# 4      https://doi.org/10.1126/science.aax4851       2019-10-24
#
#    publication_year  cited_by_count  \
# 0              2019            3181
# 1              2019             874
# 2              2019             689
# 3              2019             377
# 4              2019             373
#
#                                                  ids     type  ...  \
# 0  ["https://openalex.org/W2971836485","https://d...  article  ...
# 1  ["https://openalex.org/W2921342657","https://d...  article  ...
# 2  ["https://openalex.org/W2973189566","https://d...  article  ...
# 3  ["https://openalex.org/W2989608901","https://d...  article  ...
# 4  ["https://openalex.org/W2981612066","https://d...  article  ...
#
#                   host_organization  \
# 0  https://openalex.org/P4310320261
# 1  https://openalex.org/P4310319908
# 2  https://openalex.org/P4310320261
# 3  https://openalex.org/P4310320256
# 4  https://openalex.org/P4310315823
#
#                               host_organization_name  \
# 0                          American Physical Society
# 1                                   Nature Portfolio
# 2                          American Physical Society
# 3                                     BioMed Central
# 4  American Association for the Advancement of Sc...
#
#                               landing_page_url  \
# 0    https://doi.org/10.1103/physrevx.9.031040
# 1   https://doi.org/10.1038/s41467-019-08853-3
# 2  https://doi.org/10.1103/physrevd.100.104036
# 3    https://doi.org/10.1186/s13059-019-1835-8
# 4      https://doi.org/10.1126/science.aax4851
#
#                                              pdf_url                license  \
# 0  http://link.aps.org/pdf/10.1103/PhysRevX.9.031040                  cc-by
# 1  https://www.nature.com/articles/s41467-019-088...                  cc-by
# 2  https://link.aps.org/accepted/10.1103/PhysRevD...  publisher-specific-oa
# 3  https://genomebiology.biomedcentral.com/track/...                  cc-by
# 4                                               None                   None
#
#             version                                             topics  \
# 0  publishedVersion  [{"i":1,"score":0.9999,"id":"https://openalex....
# 1  publishedVersion  [{"i":1,"score":0.9991,"id":"https://openalex....
# 2   acceptedVersion  [{"i":1,"score":0.9999,"id":"https://openalex....
# 3  publishedVersion  [{"i":1,"score":0.9957,"id":"https://openalex....
# 4  publishedVersion  [{"i":1,"score":0.9993,"id":"https://openalex....
#
#                                             keywords is_retracted  \
# 0  [{"id":"https://openalex.org/keywords/transien...        False
# 1  [{"id":"https://openalex.org/keywords/resistom...        False
# 2  [{"id":"https://openalex.org/keywords/black-ho...        False
# 3  [{"id":"https://openalex.org/keywords/function...        False
# 4  [{"id":"https://openalex.org/keywords/terrestr...        False
#
#                                               grants
# 0  ["https://openalex.org/F4320306076","National ...
# 1                                               None
# 2  ["https://openalex.org/F4320306076","National ...
# 3                                               None
# 4                                               None
#
# [5 rows x 24 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   work_id                 350 non-null    object
#  1   title                   350 non-null    object
#  2   display_name            350 non-null    object
#  3   abstract                341 non-null    object
#  4   doi                     350 non-null    object
#  5   publication_date        350 non-null    object
#  6   publication_year        350 non-null    int32
#  7   cited_by_count          350 non-null    int32
#  8   ids                     350 non-null    object
#  9   type                    350 non-null    object
#  10  is_oa                   350 non-null    bool
#  11  source_display_name     350 non-null    object
#  12  source_id               350 non-null    object
#  13  issn_l                  350 non-null    object
#  14  host_organization       350 non-null    object
#  15  host_organization_name  350 non-null    object
#  16  landing_page_url        350 non-null    object
#  17  pdf_url                 261 non-null    object
#  18  license                 322 non-null    object
#  19  version                 330 non-null    object
#  20  topics                  350 non-null    object
#  21  keywords                276 non-null    object
#  22  is_retracted            350 non-null    bool
#  23  grants                  165 non-null    object
# dtypes: bool(2), int32(2), object(20)
# memory usage: 58.2+ KB
# None
#
#
# --- publications_main_from_WoS-Scopus_3-2.parquet ---
#                             work_id  \
# 0  https://openalex.org/W2751884637
# 1  https://openalex.org/W2765081049
# 2  https://openalex.org/W2753051611
# 3  https://openalex.org/W2766754978
# 4  https://openalex.org/W3025238321
#
#                                                title  \
# 0  Global, regional, and national incidence, prev...
# 1  GW170817: Observation of Gravitational Waves f...
# 2  Global, regional, and national age-sex specifi...
# 3  Gravitational Waves and Gamma-Rays from a Bina...
# 4  Global, regional, and national comparative ris...
#
#                                         display_name  \
# 0  Global, regional, and national incidence, prev...
# 1  GW170817: Observation of Gravitational Waves f...
# 2  Global, regional, and national age-sex specifi...
# 3  Gravitational Waves and Gamma-Rays from a Bina...
# 4  Global, regional, and national comparative ris...
#
#                                             abstract  \
# 0  <h2>Summary</h2><h3>Background</h3> As mortali...
# 1  On August 17, 2017 at 12∶41:04 UTC the Advance...
# 2  <h2>Summary</h2><h3>Background</h3> Monitoring...
# 3  On 2017 August 17, the gravitational-wave even...
# 4  BackgroundThe Global Burden of Diseases, Injur...
#
#                                               doi publication_date  \
# 0   https://doi.org/10.1016/s0140-6736(17)32154-2       2017-09-01
# 1  https://doi.org/10.1103/physrevlett.119.161101       2017-10-16
# 2   https://doi.org/10.1016/s0140-6736(17)32152-9       2017-09-01
# 3        https://doi.org/10.3847/2041-8213/aa920c       2017-10-16
# 4   https://doi.org/10.1016/s0140-6736(17)32366-8       2017-09-01
#
#    publication_year  cited_by_count  \
# 0              2017           12509
# 1              2017            8317
# 2              2017            4398
# 3              2017            3052
# 4              2017            2165
#
#                                                  ids     type  ...  \
# 0  ["https://openalex.org/W2751884637","https://d...  article  ...
# 1  ["https://openalex.org/W2765081049","https://d...  article  ...
# 2  ["https://openalex.org/W2753051611","https://d...  article  ...
# 3  ["https://openalex.org/W2766754978","https://d...  article  ...
# 4  ["https://openalex.org/W3025238321","https://d...  article  ...
#
#                   host_organization     host_organization_name  \
# 0  https://openalex.org/P4310320990                Elsevier BV
# 1  https://openalex.org/P4310320261  American Physical Society
# 2  https://openalex.org/P4310320990                Elsevier BV
# 3  https://openalex.org/P4310320083             IOP Publishing
# 4  https://openalex.org/P4310320990                Elsevier BV
#
#                                  landing_page_url  \
# 0   https://doi.org/10.1016/s0140-6736(17)32154-2
# 1  https://doi.org/10.1103/physrevlett.119.161101
# 2   https://doi.org/10.1016/s0140-6736(17)32152-9
# 3        https://doi.org/10.3847/2041-8213/aa920c
# 4   https://doi.org/10.1016/s0140-6736(17)32366-8
#
#                                              pdf_url license  \
# 0  http://www.thelancet.com/article/S014067361732...   cc-by
# 1  http://link.aps.org/pdf/10.1103/PhysRevLett.11...   cc-by
# 2  http://www.thelancet.com/article/S014067361732...   cc-by
# 3  https://iopscience.iop.org/article/10.3847/204...   cc-by
# 4  http://www.thelancet.com/article/S014067361732...   cc-by
#
#             version                                             topics  \
# 0  publishedVersion  [{"i":1,"score":0.9946,"id":"https://openalex....
# 1  publishedVersion  [{"i":1,"score":0.9998,"id":"https://openalex....
# 2  publishedVersion  [{"i":1,"score":0.9968,"id":"https://openalex....
# 3  publishedVersion  [{"i":1,"score":0.9998,"id":"https://openalex....
# 4  publishedVersion  [{"i":1,"score":0.9929,"id":"https://openalex....
#
#                                             keywords is_retracted  \
# 0  [{"id":"https://openalex.org/keywords/global-h...        False
# 1  [{"id":"https://openalex.org/keywords/kilonova...        False
# 2  [{"id":"https://openalex.org/keywords/verbal-a...        False
# 3  [{"id":"https://openalex.org/keywords/gamma-ra...        False
# 4  [{"id":"https://openalex.org/keywords/attribut...        False
#
#                                               grants
# 0  ["https://openalex.org/F4320306137","Bill and ...
# 1  ["https://openalex.org/F4320306076","National ...
# 2                                               None
# 3                                               None
# 4                                               None
#
# [5 rows x 24 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   work_id                 264 non-null    object
#  1   title                   264 non-null    object
#  2   display_name            264 non-null    object
#  3   abstract                255 non-null    object
#  4   doi                     264 non-null    object
#  5   publication_date        264 non-null    object
#  6   publication_year        264 non-null    int32
#  7   cited_by_count          264 non-null    int32
#  8   ids                     264 non-null    object
#  9   type                    264 non-null    object
#  10  is_oa                   264 non-null    bool
#  11  source_display_name     264 non-null    object
#  12  source_id               264 non-null    object
#  13  issn_l                  263 non-null    object
#  14  host_organization       263 non-null    object
#  15  host_organization_name  263 non-null    object
#  16  landing_page_url        264 non-null    object
#  17  pdf_url                 184 non-null    object
#  18  license                 220 non-null    object
#  19  version                 254 non-null    object
#  20  topics                  264 non-null    object
#  21  keywords                200 non-null    object
#  22  is_retracted            264 non-null    bool
#  23  grants                  106 non-null    object
# dtypes: bool(2), int32(2), object(20)
# memory usage: 44.0+ KB
# None

# %%
author = pd.read_parquet("search-application\data\authorships_combined_2000_2024.parquet")
publication = pd.read_parquet("search-application\data\publication_combined_2000_2024.parquet")
