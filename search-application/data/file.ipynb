# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df1 = pd.read_parquet('publications_full_dataset_2000-2024.parquet')
df1.head(5)
# Out:
#        work_id                                              title  \
# 0  W2128158076                        Geant4—a simulation toolkit
# 1  W2125899728  Comparison of Multiobjective Evolutionary Algo...
# 2  W2144476887                    No health without mental health
# 3  W2101881391  A Randomized Trial of Letrozole in Postmenopau...
# 4  W2170318505  Observation of a Narrow Charmoniumlike State i...
#
#                                         display_name  \
# 0                        Geant4—a simulation toolkit
# 1  Comparison of Multiobjective Evolutionary Algo...
# 2                    No health without mental health
# 3  A Randomized Trial of Letrozole in Postmenopau...
# 4  Observation of a Narrow Charmoniumlike State i...
#
#                                             abstract  \
# 0  GEANT4 is a toolkit for simulating the passage...
# 1  In this paper, we provide a systematic compari...
# 2  About 14% of the global burden of disease has ...
# ...

# %%
df2 = pd.read_parquet('publication.parquet')
df2.head(5)
# Out:
#                             work_id  \
# 0  https://openalex.org/W2128158076
# 1  https://openalex.org/W2125899728
# 2  https://openalex.org/W2144476887
# 3  https://openalex.org/W2101881391
# 4  https://openalex.org/W2170318505
#
#                                                title  \
# 0                        Geant4—a simulation toolkit
# 1  Comparison of Multiobjective Evolutionary Algo...
# 2                    No health without mental health
# 3  A Randomized Trial of Letrozole in Postmenopau...
# 4  Observation of a Narrow Charmoniumlike State i...
#
#                                         display_name  \
# 0                        Geant4—a simulation toolkit
# 1  Comparison of Multiobjective Evolutionary Algo...
# 2                    No health without mental health
# 3  A Randomized Trial of Letrozole in Postmenopau...
# 4  Observation of a Narrow Charmoniumlike State i...
#
#                                             abstract  \
# ...

# %%
df3 = pd.read_parquet('institutional_relationships_IN_CH.parquet')
df3.head(5)
# Out:
#                              institution_name country_code  \
# 0                                  ETH Zurich           CH
# 1                        University of Zurich           CH
# 2  European Organization for Nuclear Research           CH
# 3    École Polytechnique Fédérale de Lausanne           CH
# 4                     Paul Scherrer Institute           CH
#
#                                             work_ids  n_publications  \
# 0  W1140317928; W129941269; W137420606; W14593491...            3448
# 1  W1237811388; W137420606; W1459349108; W1481233...            2834
# 2  W129941269; W137420606; W1459349108; W14812335...            2802
# 3  W104589452; W109130197; W1140245919; W11674819...            2105
# 4  W137420606; W1484847134; W1500527695; W1507197...            1876
#
#    n_authors                                       author_names
# 0       3274  A-M Lyon; A Datta; A Nardulli; A.-M. Lyon; A. ...
# 1       2257  A Cimental Chavez; A Haeffner; A T M Tanveer H...
# ...

# %%
for i in df3['institution_name'].values:
    print(i)
# Out:
# ETH Zurich
# University of Zurich
# European Organization for Nuclear Research
# École Polytechnique Fédérale de Lausanne
# Paul Scherrer Institute
# World Health Organization
# University of Geneva
# University of Bern
# Novartis (Switzerland)
# University of Basel
# University of Lausanne
# University Hospital of Bern
# University Hospital of Zurich
# University Hospital of Basel
# Swiss Tropical and Public Health Institute
# University Hospital of Geneva
# Roche (Switzerland)
# University of Fribourg
# Swiss Federal Laboratories for Materials Science and Technology
# University of Neuchâtel
# Board of the Swiss Federal Institutes of Technology
# University Hospital of Lausanne
# SIB Swiss Institute of Bioinformatics
# Foundation for Innovative New Diagnostics
# Swiss Federal Institute for Forest, Snow and Landscape Research
# Union for International Cancer Control
# University Children's Hospital Zurich
# Swiss Federal Institute of Aquatic Science and Technology
# ...

# %%
import pandas as pd

# %%
df = pd.read_parquet('authors_summary_in_ch.parquet')
df.head()
# Out:
#      author_id          name                orcid  nWorks  total_institutions  \
# 0  A5016202220      C. Tully  0000-0001-6771-2174    1716                  38
# 1  A5019356592   J. B. Singh  0000-0001-9029-2462    1704                  38
# 2  A5062459935    K. F. Chen  0000-0003-1304-3782    1699                  29
# 3  A5107247482       S. Choi  0000-0001-6225-9876    1674                  40
# 4  A5072449178  V. Bhatnagar  0000-0002-8392-9610    1660                  26
#
#    total_countries  n_corresponding_works  \
# 0               21                      1
# 1               17                      0
# 2               13                      0
# 3               16                      0
# 4               15                      0
#
#                              institution_work_counts  \
# 0  [{'institutions': 'Princeton University, US', ...
# 1  [{'institutions': 'Panjab University, IN', 'n_...
# 2  [{'institutions': 'National Taiwan University,...
# ...

# %%
df.shape
# Out:
# (89302, 10)

# %%
df['collab_status'].value_counts()
# Out:
# collab_status
# CH       53290
# IN       28404
# Joint     5886
# Both      1722
# Name: count, dtype: int64
