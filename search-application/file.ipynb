# %%
import pandas as pd

# %%
df = pd.read_feather("data\publication_details.feather")
df.head(5)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\prans\AppData\Local\Temp\ipykernel_16368\1552576504.py:1: SyntaxWarning: invalid escape sequence '\p'
#   df = pd.read_feather("data\publication_details.feather")
#                                           abstract.s  \
# 0  Mucormycosis is a difficult to diagnose rare d...
# 1  Despite the fact that there are several antica...
# 2  Results are reported from a search for new par...
# 3  The major human pathogen Mycobacterium tubercu...
# 4  Using the data sample of 711 fb-1 of Ï'(4S) on...
#
#                                           abstract.w  \
# 0  Mucormycosis is a difficult to diagnose rare d...
# 1  Despite the fact that there are several antica...
# 2  Results are reported from a search for new par...
# 3  The major human pathogen Mycobacterium tubercu...
# 4  Using the data sample of 711 fb(-1) of Upsilon...
#
# ...

# %%
df.columns
# Out:
# Index(['abstract.s', 'abstract.w', 'affiliations', 'article title',
#        'author full names', 'author keywords', 'authors', 'book_doi_wos',
#        'conference code', 'conference date', 'conference location',
#        'conference name', 'correspondence address', 'datasource',
#        'document type', 'doi', 'end page', 'funding details.s',
#        'funding details.w', 'funding text.s', 'funding text.w',
#        'highly cited status', 'hot paper status', 'index_keywords_scopus',
#        'isbn', 'issn', 'issue', 'keywords_plus_wos', 'language', 'nAuthors',
#        'nBothAuth', 'nCountries', 'nIndAuth', 'nIndInst', 'nInst',
#        'nSwissAuth', 'nSwissInst', 'page count', 'publisher', 'pubmed id',
#        'pubNum', 'scopus_link', 'source title', 'start page', 'times_cited.s',
#        'times_cited.w', 'volume', 'wos categories', 'wos research areas',
#        'year'],
#       dtype='object')

# %%
df
# Out:
#                                               abstract.s  \
# 0      Mucormycosis is a difficult to diagnose rare d...
# 1      Despite the fact that there are several antica...
# 2      Results are reported from a search for new par...
# 3      The major human pathogen Mycobacterium tubercu...
# 4      Using the data sample of 711 fb-1 of Ï'(4S) on...
# ...                                                  ...
# 19048                                               None
# 19049                                               None
# 19050  We present a new approach for specifying and v...
# 19051  As discussed in the previous chapters, reliabl...
# 19052                                               None
#
#                                               abstract.w  \
# 0      Mucormycosis is a difficult to diagnose rare d...
# 1      Despite the fact that there are several antica...
# 2      Results are reported from a search for new par...
# ...
